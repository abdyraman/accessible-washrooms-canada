# %% [markdown]
# # Geoapify Data on Accessible Washrooms

# %%
# Dependencies
import requests
import json
import pandas as pd
# Import the API key
from config import geoapify_key

# %% [markdown]
# ## 1. What are the geocoordinates (latitude and longitude) of Brisbane, Australia?

# %%
# Construct the final URL
lang="en"
limit="100"
url = f'https://api.geoapify.com/v2/places?categories=amenity.toilet,building.toilet&conditions=wheelchair,wheelchair.yes&filter=place:512c13d96292d853c0596a04d149a5d34540f00101f90173f2040000000000c00208&lang={lang}&limit={limit}&apiKey={geoapify_key}'

# %%
# Run request

response = requests.get(url).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.33739635113083,
#                     43.70943113646696
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "E.T. Seton Washrooms",
#                 "address_line2": "Don Trail, Toronto, ON M3C 1B2, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "building": "yes",
#                         "name": "E.T. Seton Washrooms",
#                         "osm_id": 979881230,
#                         "osm_type": "w",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "E.T. Seton Washrooms, Don Trail, Toronto, ON M3C 1B2, Canada",
#                 "lat": 43.70944115,
#                 "lon": -79.33740015763222,
#                 "name": "E.T. Seton Washrooms",
#                 "place_id": "516379dde697d553c059e2f1b4a3ceda4540f00102f9010ecd673a00000000920314452e542e205365746f6e2057617368726f6f6d73",
#                 "postcode": "M3C 1B2",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Don Trail",
#                 "suburb": "Don Valley East"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.391983,
#                     43.72886800053952
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Wanless park Tennis Association - Summer Only",
#                 "address_line2": "Wanless Crescent, Old Toronto, ON M4N 1T2, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "fee": "no",
#                         "name": "Wanless park Tennis Association - Summer Only",
#                         "osm_id": 1829783791,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "Wanless park Tennis Association - Summer Only, Wanless Crescent, Old Toronto, ON M4N 1T2, Canada",
#                 "lat": 43.728868,
#                 "lon": -79.391983,
#                 "name": "Wanless park Tennis Association - Summer Only",
#                 "place_id": "51a165dd3f16d953c05986b5f08b4bdd4540f00103f901ef48106d0000000092032d57616e6c657373207061726b2054656e6e6973204173736f63696174696f6e202d2053756d6d6572204f6e6c79",
#                 "postcode": "M4N 1T2",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Wanless Crescent",
#                 "suburb": "Don Valley West"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.401732,
#                     43.72490100053959
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Locke library public toilet",
#                 "address_line2": "3083 Yonge Street, Old Toronto, ON M4N 2K7, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "fee": "no",
#                         "name": "Locke library public toilet",
#                         "osm_id": 3369502993,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "Lawrence Park",
#                 "formatted": "Locke library public toilet, 3083 Yonge Street, Old Toronto, ON M4N 2K7, Canada",
#                 "housenumber": "3083",
#                 "lat": 43.724901,
#                 "lon": -79.401732,
#                 "name": "Locke library public toilet",
#                 "place_id": "516d7022fab5d953c059de13558ec9dc4540f00103f9011189d6c80000000092031b4c6f636b65206c696272617279207075626c696320746f696c6574",
#                 "postcode": "M4N 2K7",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Yonge Street",
#                 "suburb": "Don Valley West"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.3818974,
#                     43.64784270054071
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Females",
#                 "address_line2": "77 King Street West, Old Toronto, ON M5X 1B1, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "permissive",
#                         "amenity": "toilets",
#                         "fee": "no",
#                         "female": "yes",
#                         "level": -1,
#                         "name": "Females",
#                         "operator": "Cadillac Fairview",
#                         "osm_id": 3698533559,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "toilets:position": "seated",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "district": "Financial District",
#                 "formatted": "Females, 77 King Street West, Old Toronto, ON M5X 1B1, Canada",
#                 "housenumber": "77",
#                 "lat": 43.6478427,
#                 "lon": -79.3818974,
#                 "name": "Females",
#                 "place_id": "515bdbca0171d853c05928e37582ecd24540f00103f901b72473dc0000000092030746656d616c6573",
#                 "postcode": "M5X 1B1",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "King Street West",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.3820801,
#                     43.64790120054071
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Males",
#                 "address_line2": "77 King Street West, Old Toronto, ON M5X 1B1, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "permissive",
#                         "amenity": "toilets",
#                         "fee": "no",
#                         "level": -1,
#                         "male": "yes",
#                         "name": "Males",
#                         "operator": "Cadillac Fairview",
#                         "osm_id": 3698533563,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "toilets:position": "seated;urinal",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "district": "Financial District",
#                 "formatted": "Males, 77 King Street West, Old Toronto, ON M5X 1B1, Canada",
#                 "housenumber": "77",
#                 "lat": 43.6479012,
#                 "lon": -79.3820801,
#                 "name": "Males",
#                 "place_id": "51f47c170074d853c05945ae316deed24540f00103f901bb2473dc000000009203054d616c6573",
#                 "postcode": "M5X 1B1",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "King Street West",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4278546,
#                     43.642763700540776
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "1230 Queen Street West",
#                 "address_line2": "Old Toronto, ON M6J 1H8, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "permissive",
#                         "amenity": "toilets",
#                         "fee": "no",
#                         "level": 0,
#                         "opening_hours": "Mo-Su 08:00-20:00",
#                         "osm_id": 6481835150,
#                         "osm_type": "n",
#                         "unisex": "yes",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "formatted": "1230 Queen Street West, Old Toronto, ON M6J 1H8, Canada",
#                 "housenumber": "1230",
#                 "lat": 43.6427637,
#                 "lon": -79.4278546,
#                 "place_id": "515d9c42f861db53c0597570b81446d24540f00103f9018ef4588201000000",
#                 "postcode": "M6J 1H8",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Queen Street West",
#                 "suburb": "Davenport"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4507058,
#                     43.78190620053852
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Torresdale Avenue",
#                 "address_line2": "Toronto, ON M2R 3K2, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "yes",
#                         "amenity": "toilets",
#                         "opening_hours": "24/7",
#                         "osm_id": 8830688556,
#                         "osm_type": "n",
#                         "portable": "yes",
#                         "toilets:disposal": "chemical",
#                         "unisex": "yes",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "Torresdale Avenue, Toronto, ON M2R 3K2, Canada",
#                 "lat": 43.7819062,
#                 "lon": -79.4507058,
#                 "neighbourhood": "Fisherville",
#                 "place_id": "5185c7235dd8dc53c05921ed9b8015e44540f00103f9012c9d590e02000000",
#                 "postcode": "M2R 3K2",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Torresdale Avenue",
#                 "suburb": "York Centre"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.42070816830913,
#                     43.66482762284316
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Barton Avenue",
#                 "address_line2": "Old Toronto, ON M6G 3B1, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "yes",
#                         "amenity": "toilets",
#                         "building": "yes",
#                         "fee": "no",
#                         "osm_id": 4300640,
#                         "osm_type": "w",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "Christie Pits",
#                 "formatted": "Barton Avenue, Old Toronto, ON M6G 3B1, Canada",
#                 "lat": 43.6648115,
#                 "lon": -79.42071291127228,
#                 "place_id": "510f03f4e1ecda53c0595ecb501219d54540f00102f901609f410000000000",
#                 "postcode": "M6G 3B1",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Barton Avenue",
#                 "suburb": "University\u2014Rosedale"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.34743103629978,
#                     43.675672280347584
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "McConnell Avenue",
#                 "address_line2": "Old Toronto, ON M4K 3K9, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "yes",
#                         "amenity": "toilets",
#                         "building": "yes",
#                         "building:levels": 1,
#                         "fee": "no",
#                         "osm_id": 41166602,
#                         "osm_type": "w",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.building",
#                     "details.facilities"
#                 ],
#                 "district": "Greektown",
#                 "formatted": "McConnell Avenue, Old Toronto, ON M4K 3K9, Canada",
#                 "lat": 43.67567225,
#                 "lon": -79.34743104387223,
#                 "place_id": "5178a1624f3cd653c0590c74e56d7cd64540f00102f9010a27740200000000",
#                 "postcode": "M4K 3K9",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "McConnell Avenue",
#                 "suburb": "Toronto\u2014Danforth"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.22743488990724,
#                     43.71302820899833
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Scarborough Bluffs Trail",
#                 "address_line2": "Toronto, ON M1M 1C7, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "yes",
#                         "addr:city": "Toronto",
#                         "addr:floor": "G",
#                         "amenity": "toilets",
#                         "building": "yes",
#                         "check_date": "2023-07-21",
#                         "fee": "no",
#                         "level": 0,
#                         "osm_id": 43106477,
#                         "osm_type": "w",
#                         "portable": "no",
#                         "toilets:disposal": "flush",
#                         "toilets:handwashing": "yes",
#                         "toilets:position": "seated;urinal",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "Scarborough Bluffs Trail, Toronto, ON M1M 1C7, Canada",
#                 "lat": 43.713021,
#                 "lon": -79.22740395019157,
#                 "place_id": "51be87114b8ece53c059fb62238244db4540f00102f901adc0910200000000",
#                 "postcode": "M1M 1C7",
#                 "quarter": "Scarborough Southwest",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Scarborough Bluffs Trail",
#                 "suburb": "Scarborough"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.3983943832156,
#                     43.63406757723908
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Little Norway Crescent",
#                 "address_line2": "Old Toronto, ON M5V 3N2, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "building": "yes",
#                         "fee": "no",
#                         "operator": "City of Toronto",
#                         "osm_id": 112652189,
#                         "osm_type": "w",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "district": "Bathurst Quay",
#                 "formatted": "Little Norway Crescent, Old Toronto, ON M5V 3N2, Canada",
#                 "lat": 43.63406665,
#                 "lon": -79.39839369405539,
#                 "place_id": "518db4274b7fd953c05910d9592029d14540f00102f9019defb60600000000",
#                 "postcode": "M5V 3N2",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Little Norway Crescent",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.35380836925859,
#                     43.63125585424586
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "17 Lakeshore Avenue",
#                 "address_line2": "Old Toronto, ON M5J 1Z4, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.public_and_civil",
#                     "building.toilet",
#                     "no_fee",
#                     "no_fee.no",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "yes",
#                         "addr:city": "Toronto",
#                         "addr:housenumber": 17,
#                         "addr:street": "Lakeshore Avenue",
#                         "amenity": "toilets",
#                         "building": "civic",
#                         "building:colour": "red",
#                         "building:levels": 1,
#                         "building:material": "brick",
#                         "fee": "no",
#                         "opendata:type": 115001,
#                         "operator": "City of Toronto",
#                         "osm_id": 193043050,
#                         "osm_type": "w",
#                         "toilets:disposal": "flush",
#                         "toilets:position": "seated;urinal",
#                         "unisex": "yes",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.facilities"
#                 ],
#                 "district": "Ward's Island",
#                 "formatted": "17 Lakeshore Avenue, Old Toronto, ON M5J 1Z4, Canada",
#                 "housenumber": "17",
#                 "lat": 43.63124905,
#                 "lon": -79.35378060438238,
#                 "place_id": "5112c1dbcba4d653c0597fb2e8fdccd04540f00102f9016a9a810b00000000",
#                 "postcode": "M5J 1Z4",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Lakeshore Avenue",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.39947023622865,
#                     43.69715861733134
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Lascelles Boulevard",
#                 "address_line2": "Old Toronto, ON M5P 1A2, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "building": "yes",
#                         "osm_id": 215474265,
#                         "osm_type": "w",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "Chaplin Estates",
#                 "formatted": "Lascelles Boulevard, Old Toronto, ON M5P 1A2, Canada",
#                 "lat": 43.69715865,
#                 "lon": -79.39947020017509,
#                 "place_id": "51f5149ceb90d953c05906c85a7e3cd94540f00102f90159e0d70c00000000",
#                 "postcode": "M5P 1A2",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Lascelles Boulevard",
#                 "suburb": "Toronto\u2014St. Paul's"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.3456178,
#                     43.73490360053942
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Maginn Mews",
#                 "address_line2": "Toronto, ON M3C 3R6, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "check_date": "2023-08-25",
#                         "osm_id": 495303216,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "Maginn Mews, Toronto, ON M3C 3R6, Canada",
#                 "lat": 43.7349036,
#                 "lon": -79.3456178,
#                 "place_id": "5197fa1e9a1ed653c059c503395211de4540f00103f90130ba851d00000000",
#                 "postcode": "M3C 3R6",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Maginn Mews",
#                 "suburb": "Don Valley East"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.3441212,
#                     43.734802900539414
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sampson Mews",
#                 "address_line2": "Toronto, ON M3C 0H5, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "osm_id": 495303273,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "Sampson Mews, Toronto, ON M3C 0H5, Canada",
#                 "lat": 43.7348029,
#                 "lon": -79.3441212,
#                 "place_id": "510ff7ec1406d653c0594f697d050ede4540f00103f90169ba851d00000000",
#                 "postcode": "M3C 0H5",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Sampson Mews",
#                 "suburb": "Don Valley East"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.34567690000002,
#                     43.73418610053943
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Town Square",
#                 "address_line2": "Toronto, ON M3C 0H9, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "check_date": "2023-08-25",
#                         "osm_id": 495303284,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "Town Square, Toronto, ON M3C 0H9, Canada",
#                 "lat": 43.7341861,
#                 "lon": -79.3456769,
#                 "place_id": "51e51e01921fd653c059507f65cff9dd4540f00103f90174ba851d00000000",
#                 "postcode": "M3C 0H9",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Town Square",
#                 "suburb": "Don Valley East"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.34406069999999,
#                     43.7362814005394
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "1090 Don Mills Road",
#                 "address_line2": "Toronto, ON M3C 0H5, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "osm_id": 759573151,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "1090 Don Mills Road, Toronto, ON M3C 0H5, Canada",
#                 "housenumber": "1090",
#                 "lat": 43.7362814,
#                 "lon": -79.3440607,
#                 "neighbourhood": "Don Mills",
#                 "place_id": "51af952b1705d653c05922fc0b783ede4540f00103f9019f2a462d00000000",
#                 "postcode": "M3C 0H5",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Don Mills Road",
#                 "suburb": "Don Valley East"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4098700784706,
#                     43.63091226517878
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "William G. Davis Trail",
#                 "address_line2": "Old Toronto, ON M6K 3C3, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "osm_id": 813647125,
#                         "osm_type": "w",
#                         "toilets:wheelchair": "yes",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "William G. Davis Trail, Old Toronto, ON M6K 3C3, Canada",
#                 "lat": 43.63091205,
#                 "lon": -79.40987025665262,
#                 "place_id": "51f9a8b54f3bda53c05948cbacbbc1d04540f00102f90115457f3000000000",
#                 "postcode": "M6K 3C3",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "William G. Davis Trail",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.34166165,
#                     43.64129555054079
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Unwin Avenue",
#                 "address_line2": "Old Toronto, ON M4M 1J8, Canada",
#                 "categories": [
#                     "access",
#                     "access.yes",
#                     "amenity",
#                     "amenity.toilet",
#                     "building",
#                     "building.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "yes",
#                         "amenity": "toilets",
#                         "building": "yes",
#                         "osm_id": 956601340,
#                         "osm_type": "w",
#                         "unisex": "yes",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "Port Lands",
#                 "formatted": "Unwin Avenue, Old Toronto, ON M4M 1J8, Canada",
#                 "lat": 43.641295549999995,
#                 "lon": -79.34166165,
#                 "place_id": "510943d3c8ddd553c0594e52fcf815d24540f00102f901fc93043900000000",
#                 "postcode": "M4M 1J8",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Unwin Avenue",
#                 "suburb": "Toronto\u2014Danforth"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.50112269999998,
#                     43.774269800538676
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "84 York Boulevard",
#                 "address_line2": "Toronto, ON M7A 2C5, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "osm_id": 1111967974,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "84 York Boulevard, Toronto, ON M7A 2C5, Canada",
#                 "housenumber": "84",
#                 "lat": 43.7742698,
#                 "lon": -79.5011227,
#                 "place_id": "511ff2f16412e053c0590accd7451be34540f00103f901e648474200000000",
#                 "postcode": "M7A 2C5",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "York Boulevard",
#                 "suburb": "Humber River\u2014Black Creek"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.50212819999999,
#                     43.774321500538676
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "84 York Boulevard",
#                 "address_line2": "Toronto, ON M7A 2C5, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "osm_id": 1131482562,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "North York",
#                 "formatted": "84 York Boulevard, Toronto, ON M7A 2C5, Canada",
#                 "housenumber": "84",
#                 "lat": 43.7743215,
#                 "lon": -79.5021282,
#                 "place_id": "518e5951de22e053c0599eb388f71ce34540f00103f901c20d714300000000",
#                 "postcode": "M7A 2C5",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "York Boulevard",
#                 "suburb": "Humber River\u2014Black Creek"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.383211,
#                     43.66090600054054
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "444 Yonge Street",
#                 "address_line2": "Old Toronto, ON M4Y 1X4, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "description": "Men to north women to south",
#                         "osm_id": 1191662664,
#                         "osm_type": "n",
#                         "toilets:wheelchair": "yes",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "district": "Discovery District",
#                 "formatted": "444 Yonge Street, Old Toronto, ON M4Y 1X4, Canada",
#                 "housenumber": "444",
#                 "lat": 43.660906,
#                 "lon": -79.383211,
#                 "place_id": "51eb1d6e8786d853c059a1065d9198d44540f00103f9014854074700000000",
#                 "postcode": "M4Y 1X4",
#                 "state": "Ontario",
#                 "state_code": "ON",
# ...
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "customers",
#                         "amenity": "toilets",
#                         "female": "yes",
#                         "osm_id": 9837089858,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "100 Princes' Boulevard, Old Toronto, ON M6K 3C3, Canada",
#                 "housenumber": "100",
#                 "lat": 43.6340955,
#                 "lon": -79.4140721,
#                 "place_id": "51e7eb432880da53c05991ae960a2ad14540f00103f9014214564a02000000",
#                 "postcode": "M6K 3C3",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Princes' Boulevard",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4140614,
#                     43.63406250054088
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "100 Princes' Boulevard",
#                 "address_line2": "Old Toronto, ON M6K 3C3, Canada",
#                 "categories": [
#                     "access_limited",
#                     "access_limited.customers",
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "customers",
#                         "amenity": "toilets",
#                         "male": "yes",
#                         "osm_id": 9837089859,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "100 Princes' Boulevard, Old Toronto, ON M6K 3C3, Canada",
#                 "housenumber": "100",
#                 "lat": 43.6340625,
#                 "lon": -79.4140614,
#                 "place_id": "514de262fb7fda53c059b6b8c3f528d14540f00103f9014314564a02000000",
#                 "postcode": "M6K 3C3",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Princes' Boulevard",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4128007,
#                     43.63444690054088
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "100 Princes' Boulevard",
#                 "address_line2": "Old Toronto, ON M6K 3C3, Canada",
#                 "categories": [
#                     "access_limited",
#                     "access_limited.customers",
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "customers",
#                         "amenity": "toilets",
#                         "female": "yes",
#                         "osm_id": 9837089862,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "100 Princes' Boulevard, Old Toronto, ON M6K 3C3, Canada",
#                 "housenumber": "100",
#                 "lat": 43.6344469,
#                 "lon": -79.4128007,
#                 "place_id": "510591a0536bda53c059926f588e35d14540f00103f9014614564a02000000",
#                 "postcode": "M6K 3C3",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Princes' Boulevard",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4127873,
#                     43.634404200540864
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "100 Princes' Boulevard",
#                 "address_line2": "Old Toronto, ON M6K 3C3, Canada",
#                 "categories": [
#                     "access_limited",
#                     "access_limited.customers",
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "customers",
#                         "amenity": "toilets",
#                         "male": "yes",
#                         "osm_id": 9837089863,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "100 Princes' Boulevard, Old Toronto, ON M6K 3C3, Canada",
#                 "housenumber": "100",
#                 "lat": 43.6344042,
#                 "lon": -79.4127873,
#                 "place_id": "51116d6c1b6bda53c0594fe2262834d14540f00103f9014714564a02000000",
#                 "postcode": "M6K 3C3",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Princes' Boulevard",
#                 "suburb": "Spadina\u2014Fort York"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4057108,
#                     43.653545400540644
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "399 Bathurst Street",
#                 "address_line2": "Old Toronto, ON M5T 2S8, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "male": "yes",
#                         "osm_id": 9919909576,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "Kensington Market",
#                 "formatted": "399 Bathurst Street, Old Toronto, ON M5T 2S8, Canada",
#                 "housenumber": "399",
#                 "lat": 43.6535454,
#                 "lon": -79.4057108,
#                 "place_id": "5193686e2af7d953c059fbe22c60a7d34540f00103f901c8ce454f02000000",
#                 "postcode": "M5T 2S8",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Bathurst Street",
#                 "suburb": "University\u2014Rosedale"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.4057215,
#                     43.65358030054065
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "399 Bathurst Street",
#                 "address_line2": "Old Toronto, ON M5T 2S8, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "female": "yes",
#                         "osm_id": 9919909577,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "Kensington Market",
#                 "formatted": "399 Bathurst Street, Old Toronto, ON M5T 2S8, Canada",
#                 "housenumber": "399",
#                 "lat": 43.6535803,
#                 "lon": -79.4057215,
#                 "place_id": "512e724f57f7d953c059e410f084a8d34540f00103f901c9ce454f02000000",
#                 "postcode": "M5T 2S8",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Bathurst Street",
#                 "suburb": "University\u2014Rosedale"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.40537949999998,
#                     43.652760300540656
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "399 Bathurst Street",
#                 "address_line2": "Old Toronto, ON M5T 2S8, Canada",
#                 "categories": [
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Old Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "toilets",
#                         "osm_id": 9920136099,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "unisex": "yes",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "district": "Kensington Market",
#                 "formatted": "399 Bathurst Street, Old Toronto, ON M5T 2S8, Canada",
#                 "housenumber": "399",
#                 "lat": 43.6527603,
#                 "lon": -79.4053795,
#                 "place_id": "5100bedbbcf1d953c059817947a68dd34540f00103f901a343494f02000000",
#                 "postcode": "M5T 2S8",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Bathurst Street",
#                 "suburb": "University\u2014Rosedale"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -79.18502229999999,
#                     43.82246080053765
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Aussie Walkabout",
#                 "address_line2": "Toronto, ON M1B 6K4, Canada",
#                 "categories": [
#                     "access_limited",
#                     "access_limited.customers",
#                     "amenity",
#                     "amenity.toilet",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Toronto",
#                 "country": "Canada",
#                 "country_code": "ca",
#                 "county": "Golden Horseshoe",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "access": "customers",
#                         "addr:floor": "G",
#                         "amenity": "toilets",
#                         "changing_table": "yes",
#                         "check_date": "2023-07-19",
#                         "level": 0,
#                         "osm_id": 11055548850,
#                         "osm_type": "n",
#                         "toilets:disposal": "flush",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "formatted": "Aussie Walkabout, Toronto, ON M1B 6K4, Canada",
#                 "lat": 43.8224608,
#                 "lon": -79.1850223,
#                 "place_id": "51f6e1c567d7cb53c0598d46406546e94540f00103f901b249f69202000000",
#                 "postcode": "M1B 6K4",
#                 "quarter": "Scarborough\u2014Rouge Park",
#                 "state": "Ontario",
#                 "state_code": "ON",
#                 "street": "Aussie Walkabout",
#                 "suburb": "Scarborough"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
districts = []
address = []
postcodes = []
latitudes = []
longitudes = []
names = []

for place in response["features"]:
    properties = place.get("properties", {})
    
    # Check if the key "district" exists in the "properties" dictionary
    district = properties.get("district", "N/A")
    formatted = properties.get("formatted", "N/A")
    postcode = properties.get("postcode", "N/A")
    latitude = properties.get("lat", "N/A")
    longitude = properties.get("lon", "N/A")
    name = properties.get("name", "N/A")
    
    districts.append(district)
    address.append(formatted)
    postcodes.append(postcode)
    latitudes.append(latitude)
    longitudes.append(longitude)  # Fixed the variable name
    names.append(name)

# %%
washrooms={
    "Districts":districts,
    "Address":address,
    "Postcode":postcodes,
     "Lat":latitudes,
    "Lon":longitudes,
    "Names":names
}
washrooms_df=pd.DataFrame(washrooms)
washrooms_df
# Out:
#              Districts                                            Address  \
# 0           North York  E.T. Seton Washrooms, Don Trail, Toronto, ON M...
# 1                  N/A  Wanless park Tennis Association - Summer Only,...
# 2        Lawrence Park  Locke library public toilet, 3083 Yonge Street...
# 3   Financial District  Females, 77 King Street West, Old Toronto, ON ...
# 4   Financial District  Males, 77 King Street West, Old Toronto, ON M5...
# ..                 ...                                                ...
# 62                 N/A  100 Princes' Boulevard, Old Toronto, ON M6K 3C...
# 63   Kensington Market  399 Bathurst Street, Old Toronto, ON M5T 2S8, ...
# 64   Kensington Market  399 Bathurst Street, Old Toronto, ON M5T 2S8, ...
# 65   Kensington Market  399 Bathurst Street, Old Toronto, ON M5T 2S8, ...
# 66                 N/A      Aussie Walkabout, Toronto, ON M1B 6K4, Canada
#
#    Postcode        Lat        Lon  \
# 0   M3C 1B2  43.709441 -79.337400
# 1   M4N 1T2  43.728868 -79.391983
# 2   M4N 2K7  43.724901 -79.401732
# 3   M5X 1B1  43.647843 -79.381897
# 4   M5X 1B1  43.647901 -79.382080
# ..      ...        ...        ...
# 62  M6K 3C3  43.634404 -79.412787
# 63  M5T 2S8  43.653545 -79.405711
# 64  M5T 2S8  43.653580 -79.405721
# 65  M5T 2S8  43.652760 -79.405379
# 66  M1B 6K4  43.822461 -79.185022
#
#                                             Names
# 0                            E.T. Seton Washrooms
# 1   Wanless park Tennis Association - Summer Only
# 2                     Locke library public toilet
# 3                                         Females
# 4                                           Males
# ..                                            ...
# 62                                            N/A
# 63                                            N/A
# 64                                            N/A
# 65                                            N/A
# 66                                            N/A
#
# [67 rows x 6 columns]

# %% [markdown]
# ## 2. What are the geocoordinates (latitude and longitude) of The Sydney Opera House?

# %%
# update params dict
target_city = "Sydney Opera House"

params = {
    "text": target_city,
    "apiKey": geoapify_key
}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{target_city}: {lat}, {lon}")

# %% [markdown]
# ## 3. Find the name and address of a pharmacy in Brisbane, Australia.
#
# > **Hint:** Review <https://apidocs.geoapify.com/docs/places/#categories>.

# %%
# Set the geographical coordinates for Brisbane, Australia
latitude = -27.4705
longitude = 153.0260

# Set the parameters for the type of place
categories = "healthcare.pharmacy"

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])

# %% [markdown]
# ## 4. Find a pet shop within a 5km radius from the Sydney Opera House.

# %%
# Set the geographical coordinates for the Sydney Opera House
latitude = -33.85729805
longitude = 151.21512338473752

# Set the parameters for the type of place
categories = "commercial.pet"
radius = 5000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])

# %% [markdown]
# ## 5. Find the nearest dentist to your house.
#
# > **Hint:** Use Geoapify Geocode to find your latitude and Geoapify Places to find the dentist.

# %%
# Geoapify Geocode to find latitude and longitude
my_address = "1309 Hay St, West Perth WA 6005, Australia"

params = {
    "text": my_address,
    "apiKey": geoapify_key
}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{my_address}: {lat}, {lon}")

# %%
# Set the geographical coordinates for my home
latitude = -31.9477365
longitude = 115.8387213036199

# Set the parameters for the type of place
categories = "healthcare.dentist"

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])

# %% [markdown]
# ## 6. Bonus: Find the names and addresses of the five nearest restaurants with internet access in your home city area.
#
# > **Hint:** Read about the `proximity` bias to order the results from the nearest to the farest place. Also, read about the `conditions` to identify places that provide internet access.

# %%
# Set the geographical coordinates for my home
latitude = -31.9477365
longitude = 115.8387213036199

# Set the parameters for the type of place
categories = "catering.restaurant"
conditions = "internet_access"

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "conditions":conditions,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Print the results
counter = 0

for place in response["features"]:
    print(f"Restaurant {counter+1}:")
    print(place["properties"]["name"])
    print(place["properties"]["address_line2"])
    print("*"*20)
    counter = counter + 1
    if counter == 5:
        break
